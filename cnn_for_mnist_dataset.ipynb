# %% [markdown]
# <a href="https://colab.research.google.com/github/avinash335/miniproject/blob/master/cnn_for_mnist_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.0'

# %% [markdown]
# ![mnist.ipynb.jpeg](data:image/jpeg;base64,...)

# %%
fashion = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = fashion.load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28, 1))),
model.add(tf.keras.layers.Dense(128,activation='relu')),
model.add(tf.keras.layers.Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss = 'sparse_categorical_crossentropy',metrics = 'accuracy')

# %%
history = model.fit(x_train,y_train,epochs = 7)
# Out:
# Epoch 1/7
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2049 - accuracy: 0.9489
# Epoch 2/7
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1889 - accuracy: 0.9524
# Epoch 3/7
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1842 - accuracy: 0.9538
# Epoch 4/7
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1774 - accuracy: 0.9567
# Epoch 5/7
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1697 - accuracy: 0.9589
# Epoch 6/7
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1690 - accuracy: 0.9585
# Epoch 7/7
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1655 - accuracy: 0.9594

# %%
y_pred = model.predict_classes(x_test)
y_pred
# Out:
# array([7, 2, 1, ..., 4, 5, 6])

# %%
y_pred[9]
# Out:
# 9

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9463

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[ 932,    0,    2,    2,    2,    5,    2,    2,    1,    1],
#        [   0, 1103,    0,    0,    0,    0,    3,    1,    0,    3],
#        [   5,    3,  991,   28,    5,    0,    4,   16,    4,    0],
#        [   0,    3,    0,  914,    0,   14,    0,    0,    0,    9],
#        [   0,    0,    0,    0,  892,    0,    1,    1,    4,    6],
#        [   3,    2,    1,   13,    1,  828,    7,    1,   11,    4],
#        [   3,    2,    2,    0,    7,   12,  930,    0,    4,    0],
#        [   2,    5,   17,   10,   16,    6,    0,  990,    5,   20],
#        [  35,   14,   19,   32,   23,   21,   11,    8,  939,   22],
#        [   0,    3,    0,   11,   36,    6,    0,    9,    6,  944]])

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])

# %%
model.get_weights()
# Out:
# [array([[ 0.07811963,  0.07577597, -0.06485891, ...,  0.02737945,
#           0.03569717,  0.06404775],
#         [-0.04647997,  0.07398602, -0.04127783, ...,  0.01924092,
#           0.00741274,  0.01077826],
#         [ 0.02396754, -0.00429809,  0.01464728, ..., -0.00145942,
#           0.01454559, -0.06313589],
#         ...,
#         [-0.02040353, -0.06415659, -0.01781346, ...,  0.04827901,
#          -0.05554246, -0.00514138],
#         [ 0.06019313,  0.02562493, -0.03017032, ..., -0.04390252,
#          -0.02530724, -0.07023605],
#         [-0.06363504,  0.01006201, -0.01277983, ..., -0.05827931,
#          -0.01717734, -0.01147297]], dtype=float32),
#  array([-0.03709875, -0.31166103, -0.02160736, -0.03141234, -0.05572956,
#         -0.03196957, -0.03383357, -0.28901458, -0.02658463, -0.04639183,
#         -0.10588263, -0.15350075, -0.0681604 , -0.02764073, -0.08411839,
#         -0.04905935, -0.04553115, -0.05032365, -0.07902267, -0.06502548,
# ...

# %%
model.save('mnist.h5')
